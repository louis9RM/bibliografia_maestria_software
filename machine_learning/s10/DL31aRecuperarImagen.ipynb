# %%
# Instalar OpenCV
#!pip install opencv-contrib-python

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
# cargar imagen a colores en modelo BGR
img_golden = cv2.imread('golden01.jpeg')

# %%
# Se está mostrando una imagen BGR
# usando un modelo de colores RGB
plt.imshow(img_golden)

# %%
# Se está transformando BGR a RGB
img_golden = cv2.cvtColor(img_golden,cv2.COLOR_BGR2RGB)

# %%
# Imagen que esta en RGB
plt.imshow(img_golden)

# %%
type(img_golden)
# Out:
# numpy.ndarray

# %%
img_golden.shape
# Out:
# (1040, 780, 3)

# %%
# cargar imagen en escala de grises
# a colores en modelo BGR
img_gris = mpimg.imread('grayscale-image.jpg')

# %%
plt.imshow(img_gris)

# %%
# convertir a escala de grises
img_gris = cv2.cvtColor(img_gris, cv2.COLOR_RGB2GRAY)

# %%
# Se esta mostrando una imagen en escala de grises
# como BGR
plt.imshow(img_gris)

# %%
type(img_gris)
# Out:
# numpy.ndarray

# %%
# imagen en escala de grises
img_gris.shape
# Out:
# (375, 500)

# %%
plt.imshow(img_gris,cmap = plt.get_cmap('gray'))

# %%
# Píxel [350,400]
img_gris[350,400]
# Out:
# 19

# %%
# Píxel [200,100]
img_gris[200,100]
# Out:
# 207

# %%
# cargar la imagen a colores RGB
img = mpimg.imread('golden01.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1040, 780, 3)

# %% [markdown]
# 1040 píxeles de alto y 780 píxeles de ancho con 3 canales (RGB)

# %%
# Mostrar la imagen
plt.imshow(img)

# %%
# Mostrar la imagen
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img[300,300]
# Out:
# array([204, 175, 143], dtype=uint8)

# %%
img[0,0]
# Out:
# array([253, 254, 248], dtype=uint8)

# %%
plt.imshow(img[200:450, 250:500])
plt.axis('off')
plt.show()

# %%
img[0,0]
# Out:
# array([253, 254, 248], dtype=uint8)

# %%
img[1039,779]
# Out:
# array([140, 141,  84], dtype=uint8)

# %% [markdown]
# El píxel 0,0 tiene los siguientes valores: R=253, G=254, B=248
#
# El píxel 1039,779 tiene los siguientes valores: R=140, G=141, B=84

# %%
img2 = img - 50

# %%
plt.imshow(img2)

# %%
M = np.ones(img.shape, dtype="uint8") * 100
sumado = cv2.add(img, M)
plt.imshow( sumado)

# %%
M = np.ones(img.shape, dtype="uint8") * 100
restado = cv2.subtract(img, M)
plt.imshow(restado)
